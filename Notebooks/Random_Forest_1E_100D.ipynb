# %% [markdown]
# ## Big Data Project - Model2: Random Forest
# ### This file contain code and result of Random Forest trained on review of books.jsonl file with 1 executor on 100 percent of actual dataset

# %%
import pandas as pd
import pyspark.sql.functions as F
from pyspark.sql.functions import col, count, when

# %% [markdown]
# ### --Creating and building spark session with 1 maxExecutors with 50 partition

# %%
from pyspark.sql import SparkSession

# Creating a SparkSession
spark = (
  SparkSession.builder
    .appName("AmazonReviewsUsingBERT")
    .master("yarn")
    .config("spark.dynamicAllocation.enabled", "true")
    .config("spark.shuffle.service.enabled",   "true")
    .config("spark.dynamicAllocation.minExecutors","1")
    .config("spark.dynamicAllocation.maxExecutors","1")
    .config("spark.sql.shuffle.partitions",       "50")
    .getOrCreate()
)
# Out:
# 25/05/04 20:30:50 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %% [markdown]
# ### --Data Loading and preprocessing
# #### I have turned my data as public so you should be able to run the below code, if there is problem while running then please let me know.

# %%
# Loadig the JSONL file into a Spark DataFrame
df = spark.read.json("gs://bigdataprojectdata/notebooks/jupyter/Books.jsonl")

# %%
#HANDLING MISSING VALUES
df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).show()

# %%
from pyspark.sql.functions import when
df = df.withColumn(
    "sentiment", 
    when(df["rating"] >= 4, "positive")
    .when(df["rating"] <= 3, "negative")
)

# %%
df = df.dropDuplicates(["title", "user_id"])

# %%
df = df.select("text","rating", "sentiment")

# %%
#checking if reviews "text" is a proper review i.e. contains more than 3 words. Dropping all the rows which has text containg less that 4 words
df = (df
                         .withColumn("word_count", F.size(F.split(F.col("text"),r"\s+")))
                         .filter(F.col("word_count")>=4)
                         .drop("word_count")
    )
df

# %%
#checkign the counts of sentiment rows if they are balanced or not
counts_sentiments = (
    df
        .groupBy("sentiment")
        .agg(F.count("*").alias("review_count"))
        .orderBy("sentiment")
)
counts_sentiments.show()

# %%
fractions = {"positive": 0.4, "negative": 1.0}

df = df.sampleBy("sentiment", fractions, seed=42)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import Tokenizer, StopWordsRemover, HashingTF, IDF, StringIndexer
from pyspark.ml.classification import RandomForestClassifier

# %%
# Text preprocessing
tokenizer = Tokenizer(inputCol="text", outputCol="words")
remover = StopWordsRemover(inputCol="words", outputCol="filtered")
hashingTF = HashingTF(inputCol="filtered", outputCol="rawFeatures", numFeatures=10000)
idf = IDF(inputCol="rawFeatures", outputCol="features")

# %%
# Label encoding 
indexer = StringIndexer(inputCol="sentiment", outputCol="label")

# %%
# Random Forest Classifier
rf = RandomForestClassifier(featuresCol="features", labelCol="label", numTrees=50)

# %%
# Combine all into a pipeline
pipeline = Pipeline(stages=[tokenizer, remover, hashingTF, idf, indexer, rf])

# %%
# Split data
train_df, test_df = df.randomSplit([0.8, 0.2], seed=42)

# %%
import time
start = time.time()
model = pipeline.fit(train_df)
predictions = model.transform(test_df)
end = time.time()
print(f"Training Time: {end - start:.2f} seconds")
# Out:
# 25/05/04 18:37:21 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_6 !
# 25/05/04 18:37:21 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_1 !
# 25/05/04 18:37:21 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_10 !
# 25/05/04 18:37:21 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_22 !
# 25/05/04 18:37:21 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_14 !
# 25/05/04 18:37:21 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_18 !
# 25/05/04 18:37:22 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000009 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:37:21.988]Container killed on request. Exit code is 137
# [2025-05-04 18:37:21.989]Container exited with a non-zero exit code 137.
# [2025-05-04 18:37:21.989]Killed by external signal
# .
# 25/05/04 18:37:22 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 9 for reason Container from a bad node: container_1746379126446_0001_01_000009 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:37:21.988]Container killed on request. Exit code is 137
# [2025-05-04 18:37:21.989]Container exited with a non-zero exit code 137.
# [2025-05-04 18:37:21.989]Killed by external signal
# .
# 25/05/04 18:37:22 ERROR YarnScheduler: Lost executor 9 on cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000009 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:37:21.988]Container killed on request. Exit code is 137
# [2025-05-04 18:37:21.989]Container exited with a non-zero exit code 137.
# [2025-05-04 18:37:21.989]Killed by external signal
# .
# 25/05/04 18:37:22 WARN TaskSetManager: Lost task 22.0 in stage 46.0 (TID 2085) (cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 9): ExecutorLostFailure (executor 9 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000009 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:37:21.988]Container killed on request. Exit code is 137
# [2025-05-04 18:37:21.989]Container exited with a non-zero exit code 137.
# [2025-05-04 18:37:21.989]Killed by external signal
# .
# 25/05/04 18:40:58 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_25 !
# 25/05/04 18:40:58 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_3 !
# 25/05/04 18:40:58 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_9 !
# 25/05/04 18:40:58 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_13 !
# 25/05/04 18:40:58 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_21 !
# 25/05/04 18:40:58 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_28 !
# 25/05/04 18:40:58 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_5 !
# 25/05/04 18:40:58 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_17 !
# 25/05/04 18:40:59 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000010 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 18:40:59.126]Container killed on request. Exit code is 143
# [2025-05-04 18:40:59.126]Container exited with a non-zero exit code 143.
# [2025-05-04 18:40:59.127]Killed by external signal
# .
# 25/05/04 18:40:59 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 10 for reason Container from a bad node: container_1746379126446_0001_01_000010 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 18:40:59.126]Container killed on request. Exit code is 143
# [2025-05-04 18:40:59.126]Container exited with a non-zero exit code 143.
# [2025-05-04 18:40:59.127]Killed by external signal
# .
# 25/05/04 18:40:59 ERROR YarnScheduler: Lost executor 10 on cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000010 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 18:40:59.126]Container killed on request. Exit code is 143
# [2025-05-04 18:40:59.126]Container exited with a non-zero exit code 143.
# [2025-05-04 18:40:59.127]Killed by external signal
# .
# 25/05/04 18:40:59 WARN TaskSetManager: Lost task 32.0 in stage 46.0 (TID 2097) (cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 10): ExecutorLostFailure (executor 10 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000010 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 18:40:59.126]Container killed on request. Exit code is 143
# [2025-05-04 18:40:59.126]Container exited with a non-zero exit code 143.
# [2025-05-04 18:40:59.127]Killed by external signal
# .
# 25/05/04 18:50:03 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_45 !
# 25/05/04 18:50:03 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_49 !
# 25/05/04 18:50:03 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_37 !
# 25/05/04 18:50:03 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_33 !
# 25/05/04 18:50:03 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_41 !
# 25/05/04 18:50:04 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000013 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:50:03.871]Container killed on request. Exit code is 137
# [2025-05-04 18:50:03.871]Container exited with a non-zero exit code 137.
# [2025-05-04 18:50:03.876]Killed by external signal
# .
# 25/05/04 18:50:04 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 13 for reason Container from a bad node: container_1746379126446_0001_01_000013 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:50:03.871]Container killed on request. Exit code is 137
# [2025-05-04 18:50:03.871]Container exited with a non-zero exit code 137.
# [2025-05-04 18:50:03.876]Killed by external signal
# .
# 25/05/04 18:50:04 ERROR YarnScheduler: Lost executor 13 on cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000013 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:50:03.871]Container killed on request. Exit code is 137
# [2025-05-04 18:50:03.871]Container exited with a non-zero exit code 137.
# [2025-05-04 18:50:03.876]Killed by external signal
# .
# 25/05/04 18:50:04 WARN TaskSetManager: Lost task 41.0 in stage 49.0 (TID 2175) (cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 13): ExecutorLostFailure (executor 13 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000013 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:50:03.871]Container killed on request. Exit code is 137
# [2025-05-04 18:50:03.871]Container exited with a non-zero exit code 137.
# [2025-05-04 18:50:03.876]Killed by external signal
# .
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_2 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_35 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_20 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_16 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_47 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_39 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_22 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_31 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_12 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_8 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_4 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_43 !
# 25/05/04 18:50:26 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_27 !
# 25/05/04 18:50:26 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000008 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:50:26.451]Container killed on request. Exit code is 137
# [2025-05-04 18:50:26.451]Container exited with a non-zero exit code 137.
# [2025-05-04 18:50:26.451]Killed by external signal
# .
# 25/05/04 18:50:26 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 8 for reason Container from a bad node: container_1746379126446_0001_01_000008 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:50:26.451]Container killed on request. Exit code is 137
# [2025-05-04 18:50:26.451]Container exited with a non-zero exit code 137.
# [2025-05-04 18:50:26.451]Killed by external signal
# .
# 25/05/04 18:50:26 ERROR YarnScheduler: Lost executor 8 on cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000008 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:50:26.451]Container killed on request. Exit code is 137
# [2025-05-04 18:50:26.451]Container exited with a non-zero exit code 137.
# [2025-05-04 18:50:26.451]Killed by external signal
# .
# 25/05/04 18:50:26 WARN TaskSetManager: Lost task 8.0 in stage 49.0 (TID 2177) (cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 8): ExecutorLostFailure (executor 8 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000008 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:50:26.451]Container killed on request. Exit code is 137
# [2025-05-04 18:50:26.451]Container exited with a non-zero exit code 137.
# [2025-05-04 18:50:26.451]Killed by external signal
# .
# 25/05/04 18:57:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_6 !
# 25/05/04 18:57:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_46 !
# 25/05/04 18:57:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_30 !
# 25/05/04 18:57:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_42 !
# 25/05/04 18:57:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_34 !
# 25/05/04 18:57:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_12 !
# 25/05/04 18:57:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_10 !
# 25/05/04 18:57:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_26 !
# 25/05/04 18:57:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_0 !
# 25/05/04 18:57:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_38 !
# 25/05/04 18:57:34 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000012 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:57:34.737]Container killed on request. Exit code is 137
# [2025-05-04 18:57:34.737]Container exited with a non-zero exit code 137.
# [2025-05-04 18:57:34.737]Killed by external signal
# .
# 25/05/04 18:57:34 ERROR YarnScheduler: Lost executor 12 on cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000012 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:57:34.737]Container killed on request. Exit code is 137
# [2025-05-04 18:57:34.737]Container exited with a non-zero exit code 137.
# [2025-05-04 18:57:34.737]Killed by external signal
# .
# 25/05/04 18:57:34 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 12 for reason Container from a bad node: container_1746379126446_0001_01_000012 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:57:34.737]Container killed on request. Exit code is 137
# [2025-05-04 18:57:34.737]Container exited with a non-zero exit code 137.
# [2025-05-04 18:57:34.737]Killed by external signal
# .
# 25/05/04 18:57:34 WARN TaskSetManager: Lost task 12.0 in stage 49.0 (TID 2198) (cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 12): ExecutorLostFailure (executor 12 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000012 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 18:57:34.737]Container killed on request. Exit code is 137
# [2025-05-04 18:57:34.737]Container exited with a non-zero exit code 137.
# [2025-05-04 18:57:34.737]Killed by external signal
# .
# 25/05/04 19:03:13 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_15 !
# 25/05/04 19:03:13 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_5 !
# 25/05/04 19:03:13 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_16 !
# 25/05/04 19:03:13 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_8 !
# 25/05/04 19:03:13 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_22 !
# 25/05/04 19:03:13 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_11 !
# 25/05/04 19:03:13 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_31 !
# 25/05/04 19:03:13 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000015 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:03:13.617]Container killed on request. Exit code is 143
# [2025-05-04 19:03:13.618]Container exited with a non-zero exit code 143.
# [2025-05-04 19:03:13.618]Killed by external signal
# .
# 25/05/04 19:03:14 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 15 for reason Container from a bad node: container_1746379126446_0001_01_000015 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:03:13.617]Container killed on request. Exit code is 143
# [2025-05-04 19:03:13.618]Container exited with a non-zero exit code 143.
# [2025-05-04 19:03:13.618]Killed by external signal
# .
# 25/05/04 19:03:14 ERROR YarnScheduler: Lost executor 15 on cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000015 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:03:13.617]Container killed on request. Exit code is 143
# [2025-05-04 19:03:13.618]Container exited with a non-zero exit code 143.
# [2025-05-04 19:03:13.618]Killed by external signal
# .
# 25/05/04 19:03:14 WARN TaskSetManager: Lost task 39.0 in stage 49.0 (TID 2216) (cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 15): ExecutorLostFailure (executor 15 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000015 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:03:13.617]Container killed on request. Exit code is 143
# [2025-05-04 19:03:13.618]Container exited with a non-zero exit code 143.
# [2025-05-04 19:03:13.618]Killed by external signal
# .
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_40 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_23 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_1 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_7 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_49 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_32 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_48 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_24 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_13 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_36 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_19 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_29 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_28 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_44 !
# 25/05/04 19:04:12 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_17 !
# 25/05/04 19:04:12 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000011 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:04:12.412]Container killed on request. Exit code is 143
# [2025-05-04 19:04:12.413]Container exited with a non-zero exit code 143.
# [2025-05-04 19:04:12.416]Killed by external signal
# .
# 25/05/04 19:04:12 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 11 for reason Container from a bad node: container_1746379126446_0001_01_000011 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:04:12.412]Container killed on request. Exit code is 143
# [2025-05-04 19:04:12.413]Container exited with a non-zero exit code 143.
# [2025-05-04 19:04:12.416]Killed by external signal
# .
# 25/05/04 19:04:12 ERROR YarnScheduler: Lost executor 11 on cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000011 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:04:12.412]Container killed on request. Exit code is 143
# [2025-05-04 19:04:12.413]Container exited with a non-zero exit code 143.
# [2025-05-04 19:04:12.416]Killed by external signal
# .
# 25/05/04 19:04:12 WARN TaskSetManager: Lost task 49.0 in stage 49.0 (TID 2214) (cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 11): ExecutorLostFailure (executor 11 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000011 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:04:12.412]Container killed on request. Exit code is 143
# [2025-05-04 19:04:12.413]Container exited with a non-zero exit code 143.
# [2025-05-04 19:04:12.416]Killed by external signal
# .
# 25/05/04 19:08:29 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_25 !
# 25/05/04 19:08:29 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_3 !
# 25/05/04 19:08:29 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_9 !
# 25/05/04 19:08:29 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_41 !
# 25/05/04 19:08:29 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_21 !
# 25/05/04 19:08:29 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_45 !
# 25/05/04 19:08:29 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_14 !
# 25/05/04 19:08:29 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_18 !
# 25/05/04 19:08:29 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_43 !
# 25/05/04 19:08:30 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000014 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:08:29.771]Container killed on request. Exit code is 143
# [2025-05-04 19:08:29.772]Container exited with a non-zero exit code 143.
# [2025-05-04 19:08:29.772]Killed by external signal
# .
# 25/05/04 19:08:30 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 14 for reason Container from a bad node: container_1746379126446_0001_01_000014 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:08:29.771]Container killed on request. Exit code is 143
# [2025-05-04 19:08:29.772]Container exited with a non-zero exit code 143.
# [2025-05-04 19:08:29.772]Killed by external signal
# .
# 25/05/04 19:08:30 ERROR YarnScheduler: Lost executor 14 on cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000014 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:08:29.771]Container killed on request. Exit code is 143
# [2025-05-04 19:08:29.772]Container exited with a non-zero exit code 143.
# [2025-05-04 19:08:29.772]Killed by external signal
# .
# 25/05/04 19:08:30 WARN TaskSetManager: Lost task 6.0 in stage 52.0 (TID 2292) (cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 14): ExecutorLostFailure (executor 14 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000014 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:08:29.771]Container killed on request. Exit code is 143
# [2025-05-04 19:08:29.772]Container exited with a non-zero exit code 143.
# [2025-05-04 19:08:29.772]Killed by external signal
# .
# 25/05/04 19:11:31 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_2 !
# 25/05/04 19:11:31 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_7 !
# 25/05/04 19:11:31 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_35 !
# 25/05/04 19:11:31 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_20 !
# 25/05/04 19:11:31 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_47 !
# 25/05/04 19:11:31 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_12 !
# 25/05/04 19:11:31 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_27 !
# 25/05/04 19:11:32 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000016 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:11:32.121]Container killed on request. Exit code is 143
# [2025-05-04 19:11:32.122]Container exited with a non-zero exit code 143.
# [2025-05-04 19:11:32.125]Killed by external signal
# .
# 25/05/04 19:11:32 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 16 for reason Container from a bad node: container_1746379126446_0001_01_000016 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:11:32.121]Container killed on request. Exit code is 143
# [2025-05-04 19:11:32.122]Container exited with a non-zero exit code 143.
# [2025-05-04 19:11:32.125]Killed by external signal
# .
# 25/05/04 19:11:32 ERROR YarnScheduler: Lost executor 16 on cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000016 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:11:32.121]Container killed on request. Exit code is 143
# [2025-05-04 19:11:32.122]Container exited with a non-zero exit code 143.
# [2025-05-04 19:11:32.125]Killed by external signal
# .
# 25/05/04 19:11:32 WARN TaskSetManager: Lost task 11.0 in stage 52.0 (TID 2297) (cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 16): ExecutorLostFailure (executor 16 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000016 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:11:32.121]Container killed on request. Exit code is 143
# [2025-05-04 19:11:32.122]Container exited with a non-zero exit code 143.
# [2025-05-04 19:11:32.125]Killed by external signal
# .
# 25/05/04 19:16:25 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_15 !
# 25/05/04 19:16:25 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_39 !
# 25/05/04 19:16:25 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_8 !
# 25/05/04 19:16:25 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_4 !
# 25/05/04 19:16:25 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_22 !
# 25/05/04 19:16:25 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_0 !
# 25/05/04 19:16:25 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000017 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:16:25.090]Container killed on request. Exit code is 137
# [2025-05-04 19:16:25.090]Container exited with a non-zero exit code 137.
# [2025-05-04 19:16:25.091]Killed by external signal
# .
# 25/05/04 19:16:25 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 17 for reason Container from a bad node: container_1746379126446_0001_01_000017 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:16:25.090]Container killed on request. Exit code is 137
# [2025-05-04 19:16:25.090]Container exited with a non-zero exit code 137.
# [2025-05-04 19:16:25.091]Killed by external signal
# .
# 25/05/04 19:16:25 ERROR YarnScheduler: Lost executor 17 on cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000017 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:16:25.090]Container killed on request. Exit code is 137
# [2025-05-04 19:16:25.090]Container exited with a non-zero exit code 137.
# [2025-05-04 19:16:25.091]Killed by external signal
# .
# 25/05/04 19:16:25 WARN TaskSetManager: Lost task 28.0 in stage 52.0 (TID 2308) (cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 17): ExecutorLostFailure (executor 17 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000017 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:16:25.090]Container killed on request. Exit code is 137
# [2025-05-04 19:16:25.090]Container exited with a non-zero exit code 137.
# [2025-05-04 19:16:25.091]Killed by external signal
# .
# 25/05/04 19:22:38 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_23 !
# 25/05/04 19:22:38 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_1 !
# 25/05/04 19:22:38 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_49 !
# 25/05/04 19:22:38 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_16 !
# 25/05/04 19:22:38 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_46 !
# 25/05/04 19:22:38 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_32 !
# 25/05/04 19:22:38 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_29 !
# 25/05/04 19:22:38 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_5 !
# 25/05/04 19:22:38 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_10 !
# 25/05/04 19:22:38 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_38 !
# 25/05/04 19:22:39 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000018 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:22:39.176]Container killed on request. Exit code is 143
# [2025-05-04 19:22:39.176]Container exited with a non-zero exit code 143.
# [2025-05-04 19:22:39.177]Killed by external signal
# .
# 25/05/04 19:22:39 ERROR YarnScheduler: Lost executor 18 on cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000018 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:22:39.176]Container killed on request. Exit code is 143
# [2025-05-04 19:22:39.176]Container exited with a non-zero exit code 143.
# [2025-05-04 19:22:39.177]Killed by external signal
# .
# 25/05/04 19:22:39 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 18 for reason Container from a bad node: container_1746379126446_0001_01_000018 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:22:39.176]Container killed on request. Exit code is 143
# [2025-05-04 19:22:39.176]Container exited with a non-zero exit code 143.
# [2025-05-04 19:22:39.177]Killed by external signal
# .
# 25/05/04 19:22:39 WARN TaskSetManager: Lost task 1.0 in stage 55.0 (TID 2376) (cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 18): ExecutorLostFailure (executor 18 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000018 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:22:39.176]Container killed on request. Exit code is 143
# [2025-05-04 19:22:39.176]Container exited with a non-zero exit code 143.
# [2025-05-04 19:22:39.177]Killed by external signal
# .
# 25/05/04 19:28:14 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_19 !
# 25/05/04 19:28:14 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_40 !
# 25/05/04 19:28:14 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_2 !
# 25/05/04 19:28:14 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_26 !
# 25/05/04 19:28:14 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_8 !
# 25/05/04 19:28:14 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_48 !
# 25/05/04 19:28:14 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_11 !
# 25/05/04 19:28:14 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_31 !
# 25/05/04 19:28:14 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_34 !
# 25/05/04 19:28:14 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000020 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:28:14.781]Container killed on request. Exit code is 137
# [2025-05-04 19:28:14.781]Container exited with a non-zero exit code 137.
# [2025-05-04 19:28:14.781]Killed by external signal
# .
# 25/05/04 19:28:14 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 20 for reason Container from a bad node: container_1746379126446_0001_01_000020 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:28:14.781]Container killed on request. Exit code is 137
# [2025-05-04 19:28:14.781]Container exited with a non-zero exit code 137.
# [2025-05-04 19:28:14.781]Killed by external signal
# .
# 25/05/04 19:28:14 ERROR YarnScheduler: Lost executor 20 on cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000020 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:28:14.781]Container killed on request. Exit code is 137
# [2025-05-04 19:28:14.781]Container exited with a non-zero exit code 137.
# [2025-05-04 19:28:14.781]Killed by external signal
# .
# 25/05/04 19:28:14 WARN TaskSetManager: Lost task 14.0 in stage 55.0 (TID 2403) (cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 20): ExecutorLostFailure (executor 20 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000020 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:28:14.781]Container killed on request. Exit code is 137
# [2025-05-04 19:28:14.781]Container exited with a non-zero exit code 137.
# [2025-05-04 19:28:14.781]Killed by external signal
# .
# 25/05/04 19:29:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_6 !
# 25/05/04 19:29:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_30 !
# 25/05/04 19:29:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_37 !
# 25/05/04 19:29:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_9 !
# 25/05/04 19:29:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_24 !
# 25/05/04 19:29:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_13 !
# 25/05/04 19:29:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_44 !
# 25/05/04 19:29:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_17 !
# 25/05/04 19:29:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_33 !
# 25/05/04 19:29:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_4 !
# 25/05/04 19:29:34 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000019 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:29:34.601]Container killed on request. Exit code is 143
# [2025-05-04 19:29:34.602]Container exited with a non-zero exit code 143.
# [2025-05-04 19:29:34.602]Killed by external signal
# .
# 25/05/04 19:29:34 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 19 for reason Container from a bad node: container_1746379126446_0001_01_000019 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:29:34.601]Container killed on request. Exit code is 143
# [2025-05-04 19:29:34.602]Container exited with a non-zero exit code 143.
# [2025-05-04 19:29:34.602]Killed by external signal
# .
# 25/05/04 19:29:34 ERROR YarnScheduler: Lost executor 19 on cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000019 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:29:34.601]Container killed on request. Exit code is 143
# [2025-05-04 19:29:34.602]Container exited with a non-zero exit code 143.
# [2025-05-04 19:29:34.602]Killed by external signal
# .
# 25/05/04 19:29:34 WARN TaskSetManager: Lost task 14.1 in stage 55.0 (TID 2405) (cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 19): ExecutorLostFailure (executor 19 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000019 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:29:34.601]Container killed on request. Exit code is 143
# [2025-05-04 19:29:34.602]Container exited with a non-zero exit code 143.
# [2025-05-04 19:29:34.602]Killed by external signal
# .
# 25/05/04 19:35:17 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_1 !
# 25/05/04 19:35:17 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_29 !
# 25/05/04 19:35:17 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_5 !
# 25/05/04 19:35:17 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_16 !
# 25/05/04 19:35:17 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_10 !
# 25/05/04 19:35:17 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_3 !
# 25/05/04 19:35:17 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_22 !
# 25/05/04 19:35:18 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000022 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:35:18.063]Container killed on request. Exit code is 143
# [2025-05-04 19:35:18.063]Container exited with a non-zero exit code 143.
# [2025-05-04 19:35:18.064]Killed by external signal
# .
# 25/05/04 19:35:18 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 22 for reason Container from a bad node: container_1746379126446_0001_01_000022 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:35:18.063]Container killed on request. Exit code is 143
# [2025-05-04 19:35:18.063]Container exited with a non-zero exit code 143.
# [2025-05-04 19:35:18.064]Killed by external signal
# .
# 25/05/04 19:35:18 ERROR YarnScheduler: Lost executor 22 on cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000022 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:35:18.063]Container killed on request. Exit code is 143
# [2025-05-04 19:35:18.063]Container exited with a non-zero exit code 143.
# [2025-05-04 19:35:18.064]Killed by external signal
# .
# 25/05/04 19:35:18 WARN TaskSetManager: Lost task 38.0 in stage 55.0 (TID 2420) (cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 22): ExecutorLostFailure (executor 22 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000022 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:35:18.063]Container killed on request. Exit code is 143
# [2025-05-04 19:35:18.063]Container exited with a non-zero exit code 143.
# [2025-05-04 19:35:18.064]Killed by external signal
# .
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_7 !
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_20 !
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_42 !
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_39 !
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_36 !
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_45 !
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_28 !
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_12 !
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_0 !
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_18 !
# 25/05/04 19:37:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_27 !
# 25/05/04 19:37:02 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000021 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:37:02.027]Container killed on request. Exit code is 143
# [2025-05-04 19:37:02.027]Container exited with a non-zero exit code 143.
# [2025-05-04 19:37:02.027]Killed by external signal
# .
# 25/05/04 19:37:02 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 21 for reason Container from a bad node: container_1746379126446_0001_01_000021 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:37:02.027]Container killed on request. Exit code is 143
# [2025-05-04 19:37:02.027]Container exited with a non-zero exit code 143.
# [2025-05-04 19:37:02.027]Killed by external signal
# .
# 25/05/04 19:37:02 ERROR YarnScheduler: Lost executor 21 on cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000021 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:37:02.027]Container killed on request. Exit code is 143
# [2025-05-04 19:37:02.027]Container exited with a non-zero exit code 143.
# [2025-05-04 19:37:02.027]Killed by external signal
# .
# 25/05/04 19:37:02 WARN TaskSetManager: Lost task 45.0 in stage 55.0 (TID 2423) (cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 21): ExecutorLostFailure (executor 21 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000021 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:37:02.027]Container killed on request. Exit code is 143
# [2025-05-04 19:37:02.027]Container exited with a non-zero exit code 143.
# [2025-05-04 19:37:02.027]Killed by external signal
# .
# 25/05/04 19:39:08 WARN DAGScheduler: Broadcasting large task binary with size 1102.4 KiB
# 25/05/04 19:41:04 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_15 !
# 25/05/04 19:41:04 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_25 !
# 25/05/04 19:41:04 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_35 !
# 25/05/04 19:41:04 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_47 !
# 25/05/04 19:41:04 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_21 !
# 25/05/04 19:41:04 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_41 !
# 25/05/04 19:41:05 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000023 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:41:04.904]Container killed on request. Exit code is 137
# [2025-05-04 19:41:04.904]Container exited with a non-zero exit code 137.
# [2025-05-04 19:41:04.905]Killed by external signal
# .
# 25/05/04 19:41:05 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 23 for reason Container from a bad node: container_1746379126446_0001_01_000023 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:41:04.904]Container killed on request. Exit code is 137
# [2025-05-04 19:41:04.904]Container exited with a non-zero exit code 137.
# [2025-05-04 19:41:04.905]Killed by external signal
# .
# 25/05/04 19:41:05 ERROR YarnScheduler: Lost executor 23 on cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000023 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:41:04.904]Container killed on request. Exit code is 137
# [2025-05-04 19:41:04.904]Container exited with a non-zero exit code 137.
# [2025-05-04 19:41:04.905]Killed by external signal
# .
# 25/05/04 19:41:05 WARN TaskSetManager: Lost task 2.0 in stage 58.0 (TID 2495) (cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 23): ExecutorLostFailure (executor 23 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000023 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:41:04.904]Container killed on request. Exit code is 137
# [2025-05-04 19:41:04.904]Container exited with a non-zero exit code 137.
# [2025-05-04 19:41:04.905]Killed by external signal
# .
# 25/05/04 19:44:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_23 !
# 25/05/04 19:44:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_45 !
# 25/05/04 19:44:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_6 !
# 25/05/04 19:44:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_3 !
# 25/05/04 19:44:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_32 !
# 25/05/04 19:44:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_14 !
# 25/05/04 19:44:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_43 !
# 25/05/04 19:44:01 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000024 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:44:00.962]Container killed on request. Exit code is 143
# [2025-05-04 19:44:00.962]Container exited with a non-zero exit code 143.
# [2025-05-04 19:44:00.963]Killed by external signal
# .
# 25/05/04 19:44:01 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 24 for reason Container from a bad node: container_1746379126446_0001_01_000024 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:44:00.962]Container killed on request. Exit code is 143
# [2025-05-04 19:44:00.962]Container exited with a non-zero exit code 143.
# [2025-05-04 19:44:00.963]Killed by external signal
# .
# 25/05/04 19:44:01 ERROR YarnScheduler: Lost executor 24 on cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000024 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:44:00.962]Container killed on request. Exit code is 143
# [2025-05-04 19:44:00.962]Container exited with a non-zero exit code 143.
# [2025-05-04 19:44:00.963]Killed by external signal
# .
# 25/05/04 19:44:01 WARN TaskSetManager: Lost task 10.0 in stage 58.0 (TID 2504) (cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 24): ExecutorLostFailure (executor 24 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000024 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:44:00.962]Container killed on request. Exit code is 143
# [2025-05-04 19:44:00.962]Container exited with a non-zero exit code 143.
# [2025-05-04 19:44:00.963]Killed by external signal
# .
# 25/05/04 19:44:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_7 !
# 25/05/04 19:44:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_46 !
# 25/05/04 19:44:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_4 !
# 25/05/04 19:44:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_0 !
# 25/05/04 19:44:50 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000026 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:44:50.801]Container killed on request. Exit code is 137
# [2025-05-04 19:44:50.801]Container exited with a non-zero exit code 137.
# [2025-05-04 19:44:50.802]Killed by external signal
# .
# 25/05/04 19:44:50 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 26 for reason Container from a bad node: container_1746379126446_0001_01_000026 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:44:50.801]Container killed on request. Exit code is 137
# [2025-05-04 19:44:50.801]Container exited with a non-zero exit code 137.
# [2025-05-04 19:44:50.802]Killed by external signal
# .
# 25/05/04 19:44:50 ERROR YarnScheduler: Lost executor 26 on cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000026 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:44:50.801]Container killed on request. Exit code is 137
# [2025-05-04 19:44:50.801]Container exited with a non-zero exit code 137.
# [2025-05-04 19:44:50.802]Killed by external signal
# .
# 25/05/04 19:44:50 WARN TaskSetManager: Lost task 7.0 in stage 58.0 (TID 2501) (cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 26): ExecutorLostFailure (executor 26 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000026 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:44:50.801]Container killed on request. Exit code is 137
# [2025-05-04 19:44:50.801]Container exited with a non-zero exit code 137.
# [2025-05-04 19:44:50.802]Killed by external signal
# .
# 25/05/04 19:53:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_2 !
# 25/05/04 19:53:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_29 !
# 25/05/04 19:53:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_12 !
# 25/05/04 19:53:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_9 !
# 25/05/04 19:53:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_18 !
# 25/05/04 19:53:34 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_24 !
# 25/05/04 19:53:34 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000027 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:53:34.776]Container killed on request. Exit code is 137
# [2025-05-04 19:53:34.777]Container exited with a non-zero exit code 137.
# [2025-05-04 19:53:34.778]Killed by external signal
# .
# 25/05/04 19:53:34 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 27 for reason Container from a bad node: container_1746379126446_0001_01_000027 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:53:34.776]Container killed on request. Exit code is 137
# [2025-05-04 19:53:34.777]Container exited with a non-zero exit code 137.
# [2025-05-04 19:53:34.778]Killed by external signal
# .
# 25/05/04 19:53:34 ERROR YarnScheduler: Lost executor 27 on cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000027 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:53:34.776]Container killed on request. Exit code is 137
# [2025-05-04 19:53:34.777]Container exited with a non-zero exit code 137.
# [2025-05-04 19:53:34.778]Killed by external signal
# .
# 25/05/04 19:53:34 WARN TaskSetManager: Lost task 34.0 in stage 58.0 (TID 2524) (cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 27): ExecutorLostFailure (executor 27 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000027 on host: cluster-c2aa-w-0.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 137. Diagnostics: [2025-05-04 19:53:34.776]Container killed on request. Exit code is 137
# [2025-05-04 19:53:34.777]Container exited with a non-zero exit code 137.
# [2025-05-04 19:53:34.778]Killed by external signal
# .
# 25/05/04 19:54:42 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_1 !
# 25/05/04 19:54:42 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_49 !
# 25/05/04 19:54:42 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_20 !
# 25/05/04 19:54:42 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_16 !
# 25/05/04 19:54:42 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_31 !
# 25/05/04 19:54:42 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_5 !
# 25/05/04 19:54:42 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_8 !
# 25/05/04 19:54:42 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_11 !
# 25/05/04 19:54:42 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_27 !
# 25/05/04 19:54:42 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_127_38 !
# 25/05/04 19:54:43 WARN YarnAllocator: Container from a bad node: container_1746379126446_0001_01_000025 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:54:42.678]Container killed on request. Exit code is 143
# [2025-05-04 19:54:42.679]Container exited with a non-zero exit code 143.
# [2025-05-04 19:54:42.679]Killed by external signal
# .
# 25/05/04 19:54:43 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 25 for reason Container from a bad node: container_1746379126446_0001_01_000025 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:54:42.678]Container killed on request. Exit code is 143
# [2025-05-04 19:54:42.679]Container exited with a non-zero exit code 143.
# [2025-05-04 19:54:42.679]Killed by external signal
# .
# 25/05/04 19:54:43 ERROR YarnScheduler: Lost executor 25 on cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal: Container from a bad node: container_1746379126446_0001_01_000025 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:54:42.678]Container killed on request. Exit code is 143
# [2025-05-04 19:54:42.679]Container exited with a non-zero exit code 143.
# [2025-05-04 19:54:42.679]Killed by external signal
# .
# 25/05/04 19:54:43 WARN TaskSetManager: Lost task 37.0 in stage 58.0 (TID 2527) (cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal executor 25): ExecutorLostFailure (executor 25 exited caused by one of the running tasks) Reason: Container from a bad node: container_1746379126446_0001_01_000025 on host: cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal. Exit status: 143. Diagnostics: [2025-05-04 19:54:42.678]Container killed on request. Exit code is 143
# [2025-05-04 19:54:42.679]Container exited with a non-zero exit code 143.
# [2025-05-04 19:54:42.679]Killed by external signal
# .
# [Stage 61:=====================================================>(149 + 1) / 150]
# Training Time: 7432.20 seconds

# %%
predictions.select("text", "sentiment", "prediction").show(10)
# Out:
# [Stage 64:>                                                         (0 + 1) / 1]
# +--------------------+---------+----------+
# |                text|sentiment|prediction|
# +--------------------+---------+----------+
# |!<br />How to des...| positive|       0.0|
# |" 'Keeping it Rea...| positive|       0.0|
# |" I found the boo...| positive|       0.0|
# |"$30 Writing Scho...| positive|       0.0|
# |"...Most people a...| negative|       0.0|
# |"...war is a secu...| positive|       0.0|
# |"22 Britannia Roa...| positive|       0.0|
# |"A Dragons Tale" ...| positive|       0.0|
# |"A Summer Tale of...| positive|       0.0|
# |"A Tree Grows in ...| positive|       0.0|
# +--------------------+---------+----------+
# only showing top 10 rows

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# [Stage 67:======================================================> (49 + 1) / 50]
# Test Accuracy: 0.6702

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
bce = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction",
                                    labelCol="label",
                                    metricName="areaUnderROC")
roc_auc = bce.evaluate(predictions)

# %%
f1 = evaluator.setMetricName("f1").evaluate(predictions)

# %%
print(f"Test ROC AUC = {roc_auc:.4f}")
print(f"Test Accuracy = {accuracy:.4f}")
print(f"Test F1 Score = {f1:.4f}")
# Out:
# Test ROC AUC = 0.7609
# Test Accuracy = 0.6702
# Test F1 Score = 0.5383

# %%
from pyspark import SparkContext

sc = spark.sparkContext
executors = sc._jsc.sc().getExecutorMemoryStatus().keySet()
print(f"Active Executors: {executors}")
# Out:
# Active Executors: Set(cluster-c2aa-m.northamerica-south1-b.c.academic-timing-458516-v2.internal:41221, cluster-c2aa-w-1.northamerica-south1-b.c.academic-timing-458516-v2.internal:36857)
